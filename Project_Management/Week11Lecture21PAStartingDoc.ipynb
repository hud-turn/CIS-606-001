# %% [markdown]
# 1. Suppose you remain the project manager in charge of one of the three projects below. Create a Gantt chart for your project.\
#     • Improve the service of your organization’s IT help desk\
#     • Help senior citizens in nursing homes combat privacy risks\
#     • Redesign the website of a smart watch company
#
#
#
#
#
# 2. Learn about Open AI’s 4o image generator.\
#     Imagine you are the project manager in charge of developing and launching such an image generator for Open AI.\
#     What risks will you consider putting in the risk management matrix below?
#
#
#     |Likelihood| Acceptable | Tolerable | Undesirable | Intolerable |
#     |----------|------------|:----------|:-----------:|-------------|
#     |Improbable| Row 1 Col 1|Row 1 Col 2| Row 1 Col 3 | Row 1 Col 4 |
#     |Possible  | Row 2 Col 1|Row 2 Col 2| Row 2 Col 3 | Row 2 Col 4 |
#     |Probable  | Row 3 Col 1|Row 3 Col 2| Row 3 Col 3 | Row 3 Col 4 |
