# %% [markdown]
# Data Collection vs Data Processing vs Data Analysis
#
# Data Collection:
# Gather info from databases, API, and/or sensors
# Consider if you are looking at correlation or causality
# Implications of your measurements
#
# Data Processing:
# Clean data by removing duplicates and invalid values
# Organize data
# Extract features
#
# Data Analysis:
# Apply Statistical Analysis
# Build and evaluate ML techniques:
#     Supervised
#     Unsupervised Learning
#
#
# Decision Trees:
# Hyperparameters:
#     configure variables to set before model training
#     Examples: max_depth, min_samples_split
#     Training, validation, testing datasets
#
# Overfitting vs Underfitting:
#     Overfitting: model learns noise, poor generalization
#     Underfitting: model too simple, misses patterns
#     Balance complexity and generalization
#
#                                                 [Actual]
#                                   |spam (positive) | non-spam (negative)
#                spam(positive)     | True Positive  | False Positive     |
#                non-spam (negative)| False Negative | True Negative      |
#
#             Accuracy = (TP + TN) / (TP + TN + FP + FN) # overall correctness
#             Accuracy is useful when classes are balanced, but can be misleading with imbalanced datasets.
#
#             Precision = TP / (TP + FP) # of predicted positives that are actual positives
#             Precision  is important when false positives are costly, for example in email spam detection
#
#
#             Recall = TP / (TP + FN) #of actual positives that are predicted positives
#             Recall is important when false negatives are costly, for example in medical diagnoses
#
#             F1 Score = 2 * (Precision * Recall) / (Precision + Recall) # harmonic mean of precision and recall
